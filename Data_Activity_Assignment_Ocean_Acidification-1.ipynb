# %% [markdown]
# ## Data Activity Assignment: Ocean Acidification
# Improve upon the preview graphic for the OceanSODA project seen below using the most recent published version of the data file available [here](https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.nodc:0220059) or at [from Canvas](https://rutgers.instructure.com/files/37318699/download?download_frd=1)
#
# ![image.png](attachment:070c0c38-a80f-4ef0-9407-29570a1ba196.png)

# %%
# Our usual imports
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cool_maps.plot as cplt
import cartopy.crs as ccrs
import cmocean.cm as cmo
import numpy as np

# %matplotlib inline

# %%
file = 'OceanSODA_ETHZ-v2023.OCADS.01_1982-2022.nc'
ds   = xr.open_dataset(file)
ds
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:          (time: 492, lat: 180, lon: 360, region: 4)
# Coordinates:
#   * time             (time) datetime64[ns] 4kB 1982-01-15 ... 2022-12-15
#   * lat              (lat) float64 1kB -89.5 -88.5 -87.5 ... 87.5 88.5 89.5
#   * lon              (lon) float64 3kB -179.5 -178.5 -177.5 ... 178.5 179.5
#   * region           (region) <U7 112B 'global' 'north' 'tropics' 'south'
# Data variables: (12/28)
#     talk             (time, lat, lon) float32 128MB ...
#     dic              (time, lat, lon) float32 128MB ...
#     spco2            (time, lat, lon) float32 128MB ...
#     sfco2            (time, lat, lon) float32 128MB ...
#     ph_total         (time, lat, lon) float32 128MB ...
#     ph_free          (time, lat, lon) float32 128MB ...
#     ...               ...
#     area             (lat, lon) float32 259kB ...
#     fgco2_reg        (region, time) float32 8kB ...
#     area_reg         (region) float32 16B ...
# ...

# %% [markdown]
# ## #0. Describe the data set. What variables does it contain? Over what spatiotemporal range?

# %% [markdown]
# ## #1. Recreate the preview graphic for the first time record in the file. Be sure to match colormaps as best as possible.

# %% [markdown]
# ## #2. Take the time mean of the file then recreate the preview graphic.

# %% [markdown]
# ## #3. Improve on the preview graphic by turning it into an animation going through the entire time record. Be sure to lock your colorbar ranges so they do not vary with each timestep.

# %% [markdown]
# ## #4. What changes do you see across each of the 6 plots as the animation progresses? Describe each subplot's changes in detail.
